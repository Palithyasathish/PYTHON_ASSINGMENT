# %% [markdown]
# # seaborn

# %%
# Data Visualization with Seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('iris.csv')

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Line chart

# %%
sns.lineplot(x=df['sepal.length'],y=df['sepal.width'],data=df)
plt.show()

# %%
sns.lineplot(x='sepal.length',y='sepal.width',data=df)
plt.show()

# %%
# setting limits for X - axis

# %%
sns.lineplot(x='sepal.length',y='sepal.width',data=df)
plt.xlim(5)
plt.show()

# %% [markdown]
# # Customizing Seaborn plots

# %% [markdown]
# 1. darkgrid
# 2. white grid
# 3. dark
# 4. white
# 5. ticks

# %%
# set_style() is to set style of figure
# set_style('dark')

# %%
sns.lineplot(x='sepal.length',y='sepal.width',data=df)
plt.xlim(5)
sns.set_style('white')
plt.show()

# %%
sns.lineplot(x='sepal.length',y='sepal.width',data=df)
plt.xlim(5)
sns.set_style('darkgrid')
plt.show()

# %%
sns.lineplot(x='sepal.length',y='sepal.width',data=df)
plt.xlim(5)
sns.set_style('dark')
plt.show()

# %%
sns.lineplot(x='sepal.length',y='sepal.width',data=df)
plt.xlim(5)
sns.set_style('ticks')
plt.show()

# %% [markdown]
# # color palette

# %%
p = sns.color_palette()
sns.palplot(p)
plt.show()

# %%
p = sns.color_palette('Greens',11)
sns.palplot(p)
plt.show()

# %%
p = sns.color_palette('Reds',11)
sns.palplot(p)
plt.show()

# %%
p = sns.color_palette('Blues',11)
sns.palplot(p)
plt.show()

# %% [markdown]
# # subplots

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(4,2))
x = np.linspace(0,10,1000)
y = np.sin(x)
z = np.cos(x)
plt.subplot(1,2,1)
sns.lineplot(x=x,y=y,color='r',linewidth=4)
plt.subplot(1,2,2)
sns.lineplot(x=x,y=z,color='g',linewidth=6)
sns.set_style('darkgrid')
plt.show()

# %% [markdown]
# # FacetGrid

# %%
# this helps in visualizing distribution of one variable as well as the relation
#relationship between multiple variables separately within subsets of your dataset
#using multiple panels

# %% [markdown]
# 1. it takes dataframe as input and the names of the variables that will
#    form the row,column dimensions of the grid.
# 2. the variables should be categorical and the data at each level of the
#    variable will be used for facet along that axis

# %%
plot = sns.FacetGrid(df,col='variety')
plot.map(plt.plot,'sepal.width')
plt.show()

# %%
plot = sns.FacetGrid(df,col='variety')
plot.map(plt.plot,'petal.width')
plt.show()

# %% [markdown]
# # Relational Plots

# %%
# relplot()
sns.relplot(x='sepal.width',y='variety',data=df)
plt.show()

# %%
# relplot()
sns.relplot(x='sepal.width',y='petal.width',data=df,color='r')
plt.show()

# %% [markdown]
# # scatter plots

# %%
sns.scatterplot(x='sepal.width',y='petal.width',data=df,color='y')
plt.show()

# %% [markdown]
# # bar plots

# %%
plt.figure(figsize=(4,2))
sns.barplot(x='variety',y='sepal.length',data=df)
plt.show()

# %% [markdown]
# # Count Plot

# %%
plt.figure(figsize=(10,2))
sns.countplot(x='sepal.width',data=df)
plt.show()

# %% [markdown]
# # box Plot

# %%
plt.figure(figsize=(4,2))
sns.boxplot(x='variety',y='sepal.width',data=df)
plt.show()

# %%
plt.figure(figsize=(4,2))
sns.boxplot(x='variety',y='petal.width',data=df)
plt.show()

# %%
plt.figure(figsize=(4,2))
sns.boxplot(x='variety',y='sepal.length',data=df)
plt.show()

# %% [markdown]
# # Distplot

# %%
# it plots distribution of data along with histogram
plt.figure(figsize=(4,2))
sns.distplot(df['sepal.width'],color='r')
plt.show()

# %%
plt.figure(figsize=(4,2))
sns.distplot(df['petal.width'],color='g')
plt.show()

# %% [markdown]
# # pairplot

# %%
# it represents pair wise relation across the entire data frame 
#and supports an additional argument called hue for categorical separation

# %%
sns.pairplot(data=df,hue='variety')
plt.show()
